# %%
# all libraries required
import pandas as pd  # for data handling
import matplotlib.pyplot as plt  # for graphs
from sklearn.feature_extraction.text import TfidfVectorizer  # to convert text to numbers
from sklearn.linear_model import LogisticRegression  # model for prediction
from sklearn.model_selection import train_test_split  # to split training and test data
from sklearn.metrics import accuracy_score, classification_report  #it willcheck performance

# %%
import pandas as pd
# this will load the dataset i have prepared for reviews
path = "/content/drive/MyDrive/dataset /2_Anylisis.csv"
df = pd.read_csv(path)
df.head(30)  # 30 reviews so (30)
# Out:
#                                         Review Sentiment
# 0                         I love this product!  Positive
# 1           Amazing quality and fast delivery.  Positive
# 2           It works perfectly, I'm impressed.  Positive
# 3                     The design is very good.  Positive
# 4                  It met all my expectations.  Positive
# 5               This is exactly what I needed!  Positive
# 6          The color and design are beautiful.  Positive
# 7               Super helpful and easy to use.  Positive
# 8                  Works better than expected.  Positive
# 9                    I had a great experience.  Positive
# 10                          It is very unique.  Positive
# 11          I would definitely recommend this.  Positive
# 12    High-quality material and smooth finish.  Positive
# 13        Exceeded my expectations completely.  Positive
# 14                  Fantastic value for money.  Positive
# 15           This is the worst thing I bought.  Negative
# 16              I am not happy with this item.  Negative
# 17       Completely useless and disappointing.  Negative
# 18        Poor performance and bad experience.  Negative
# 19                        Not worth the money.  Negative
# 20          I want a refund, this is horrible.  Negative
# 21                     It broke after one use.  Negative
# 22                       Bad customer service.  Negative
# 23            The quality was awful and cheap.  Negative
# 24             Very dissatisfied, total waste.  Negative
# 25                   Extremely buggy and slow.  Negative
# 26        Didn't match the description at all.  Negative
# 27   This caused more problems than solutions.  Negative
# 28  Terrible experience, will never buy again.  Negative
# 29             It stopped working in two days.  Negative

# %%
# it will Convert sentiment column into numeric values using dictionary
d = {'Positive': 1, 'Negative': 0}
df['Sentiment'] = df['Sentiment'].map(d)

X = df['Review']  # input is the review text
y = df['Sentiment']  # output is the sentiment

combine = pd.concat([X, y], axis=1)  # show input and output colum together

print(combine.head(31))
# Out:
#                                         Review  Sentiment
# 0                         I love this product!          1
# 1           Amazing quality and fast delivery.          1
# 2           It works perfectly, I'm impressed.          1
# 3                     The design is very good.          1
# 4                  It met all my expectations.          1
# 5               This is exactly what I needed!          1
# 6          The color and design are beautiful.          1
# 7               Super helpful and easy to use.          1
# 8                  Works better than expected.          1
# 9                    I had a great experience.          1
# 10                          It is very unique.          1
# 11          I would definitely recommend this.          1
# 12    High-quality material and smooth finish.          1
# 13        Exceeded my expectations completely.          1
# 14                  Fantastic value for money.          1
# 15           This is the worst thing I bought.          0
# 16              I am not happy with this item.          0
# 17       Completely useless and disappointing.          0
# 18        Poor performance and bad experience.          0
# 19                        Not worth the money.          0
# 20          I want a refund, this is horrible.          0
# 21                     It broke after one use.          0
# 22                       Bad customer service.          0
# 23            The quality was awful and cheap.          0
# 24             Very dissatisfied, total waste.          0
# 25                   Extremely buggy and slow.          0
# 26        Didn't match the description at all.          0
# 27   This caused more problems than solutions.          0
# 28  Terrible experience, will never buy again.          0
# 29             It stopped working in two days.          0

# %%
#Convert text into TF-IDF numbers
vectorizer = TfidfVectorizer()  # create vectorizer
X_tfidf = vectorizer.fit_transform(X)  # apply to the review text

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=0)

#Train model
model = LogisticRegression()  # creatation of logistic regression
model.fit(X_train, y_train)  # train

# this will Predict the sentiment using test data
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))  # to show accuracy
# Out:
# Accuracy: 0.5

# %%
# Test the model with a new review
test_review = ["The product was amazing and I loved it!"]
test_review_tfidf = vectorizer.transform(test_review)
prediction = model.predict(test_review_tfidf)  # prediction based on the above review

if prediction[0] == 1:
    print("Predicted Sentiment: Positive :) ")
else:
    print("Predicted Sentiment: Negative :( ")
# Out:
# Predicted Sentiment: Positive :)
